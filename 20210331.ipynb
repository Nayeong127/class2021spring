# %% [markdown]
# <a href="https://colab.research.google.com/github/Nayeong127/class2021Spring/blob/main/20210331.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 아
# pitch 213Hz
# intensity 74.62 dB
# formant 1021 Hz / 1915 Hz
# duration 0.498 sec
#
#
# # 애
# pitch 213Hz
# intensity 76.22 dB
# formant 766 Hz / 957.7 Hz
# duration 0.517 sec
#
# ***저의 '애'는 formant가 네 개로 보입니다 ㅠ.ㅠ !! 1,2번이 겹쳐있는건가요??***

# %% [markdown]
# ![20210331.png](data:image/png;base64,...)
