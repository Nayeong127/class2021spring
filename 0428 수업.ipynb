# %% [markdown]
# <a href="https://colab.research.google.com/github/Nayeong127/class2021Spring/blob/main/0428%20%EC%88%98%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import IPython.display as ipd
import numpy as np
from scipy.signal import lfilter

# %%
theta=np.pi #얘 지금 180이다
np.sin(theta)
# Out:
# 1.2246467991473532e-16

# %% [markdown]
# 1.2246467991473532e-16
# -16은 유효숫자. 0.000000000012라는 뜻~

# %%
theta=np.pi/6 #얘 지금 30도다
np.sin(theta)
# Out:
# 0.49999999999999994

# %%
theta=np.pi*0 #얘 지금 0이다
np.sin(theta)
# Out:
# 0.0

# %% [markdown]
# i 대신 1j라고 쓰는 거임~
#
# ![image.png](data:image/png;base64,...)

# %%
theta=np.pi*0
np.exp(theta*1j)
# Out:
# (1+0j)

# %% [markdown]
# 이거 찍으면 (1,0)

# %%
theta=np.pi/2
np.exp(theta*1j)
# Out:
# (6.123233995736766e-17+1j)

# %%
theta=np.pi
np.exp(theta*1j)
# Out:
# (-1+1.2246467991473532e-16j)

# %% [markdown]
# -1,0i
# ->(-1,0)

# %%
theta=np.pi*3/2
np.exp(theta*1j)
# Out:
# (-1.8369701987210297e-16-1j)

# %% [markdown]
# 0-i
# (0,-1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# 규칙성이 있다. 이걸 다 이으면 동그라미가 될듯?!
# ![image.png](data:image/png;base64,...)
